# %%
import pandas as pd

# %%
bookings = pd.read_csv(r"C:\\Users\perum\Desktop\Code Basics Projects\Hospitality insights\Input Files\fact_bookings.csv")

# %%
bookings.head(10)
# Out:
#           booking_id  property_id booking_date check_in_date checkout_date  \
# 0   May012216558RT11        16558   2022-04-27    2022-05-01    2022-05-02
# 1   May012216558RT12        16558   2022-04-30    2022-05-01    2022-05-02
# 2   May012216558RT13        16558   2022-04-28    2022-05-01    2022-05-04
# 3   May012216558RT14        16558   2022-04-28    2022-05-01    2022-05-02
# 4   May012216558RT15        16558   2022-04-27    2022-05-01    2022-05-02
# 5   May012216558RT16        16558   2022-05-01    2022-05-01    2022-05-03
# 6   May012216558RT17        16558   2022-04-28    2022-05-01    2022-05-06
# 7   May012216558RT18        16558   2022-04-26    2022-05-01    2022-05-03
# 8   May012216558RT19        16558   2022-04-30    2022-05-01    2022-05-02
# 9  May012216558RT110        16558   2022-04-28    2022-05-01    2022-05-02
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# ...

# %%
bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134590 entries, 0 to 134589
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134590 non-null  object
#  1   property_id        134590 non-null  int64
#  2   booking_date       134590 non-null  object
#  3   check_in_date      134590 non-null  object
#  4   checkout_date      134590 non-null  object
#  5   no_guests          134590 non-null  int64
#  6   room_category      134590 non-null  object
#  7   booking_platform   134590 non-null  object
#  8   ratings_given      56683 non-null   float64
#  9   booking_status     134590 non-null  object
#  10  revenue_generated  134590 non-null  int64
#  11  revenue_realized   134590 non-null  int64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 12.3+ MB

# %%
bookings.describe().round(2)
# Out:
#        property_id  no_guests  ratings_given  revenue_generated  \
# count    134590.00  134590.00       56683.00          134590.00
# mean      18061.11       2.04           3.62           14916.01
# std        1093.06       1.03           1.24            6452.87
# min       16558.00       1.00           1.00            6500.00
# 25%       17558.00       1.00           3.00            9900.00
# 50%       17564.00       2.00           4.00           13500.00
# 75%       18563.00       2.00           5.00           18000.00
# max       19563.00       6.00           5.00           45220.00
#
#        revenue_realized
# count         134590.00
# mean           12696.12
# std             6928.11
# min             2600.00
# 25%             7600.00
# 50%            11700.00
# 75%            15300.00
# max            45220.00

# %%
bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77907
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
bookings.loc[bookings['booking_status'].isin(['Cancelled','No Show']), 'ratings_given']='Not Applicable'

# %%
bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        37728
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
bookings.loc[bookings['ratings_given'].isin(['Not Applicable']), 'ratings_given']= 0

# %%
bookings['ratings_given']=bookings['ratings_given'].astype('float64')

# %%
bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134590 entries, 0 to 134589
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134590 non-null  object
#  1   property_id        134590 non-null  int64
#  2   booking_date       134590 non-null  object
#  3   check_in_date      134590 non-null  object
#  4   checkout_date      134590 non-null  object
#  5   no_guests          134590 non-null  int64
#  6   room_category      134590 non-null  object
#  7   booking_platform   134590 non-null  object
#  8   ratings_given      96862 non-null   object
#  9   booking_status     134590 non-null  object
#  10  revenue_generated  134590 non-null  int64
#  11  revenue_realized   134590 non-null  int64
# dtypes: int64(4), object(8)
# memory usage: 12.3+ MB

# %%
bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        37728
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
import numpy as np
bookings.loc[~bookings['ratings_given'].between(1,5),'ratings_given']=np.nan

# %%
bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77907
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
agr_book = pd.read_csv(r"C:\\Users\perum\Desktop\Code Basics Projects\Hospitality insights\Input Files\fact_aggregated_bookings.csv")

# %%
agr_book.head(10)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559     01-May-22           RT1                   25        30
# 1        19562     01-May-22           RT1                   28        30
# 2        19563     01-May-22           RT1                   23        30
# 3        17558     01-May-22           RT1                   13        19
# 4        16558     01-May-22           RT1                   18        19
# 5        17560     01-May-22           RT1                   28        40
# 6        19558     01-May-22           RT1                   25        40
# 7        19560     01-May-22           RT1                   23        26
# 8        17561     01-May-22           RT1                   22        26
# 9        16560     01-May-22           RT1                   24        34

# %%
agr_book.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               0
# dtype: int64

# %%
agr_book.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9200 entries, 0 to 9199
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_id          9200 non-null   int64
#  1   check_in_date        9200 non-null   object
#  2   room_category        9200 non-null   object
#  3   successful_bookings  9200 non-null   int64
#  4   capacity             9200 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 359.5+ KB

# %%
agr_book.describe().round(2)
# Out:
#        property_id  successful_bookings  capacity
# count      9200.00              9200.00   9200.00
# mean      18040.64                14.63     25.28
# std        1099.82                 7.59     11.44
# min       16558.00                 1.00      3.00
# 25%       17558.00                 9.00     18.00
# 50%       17564.00                14.00     25.00
# 75%       18563.00                19.00     34.00
# max       19563.00                43.00     50.00

# %%
agr_book.columns
# Out:
# Index(['property_id', 'check_in_date', 'room_category', 'successful_bookings',
#        'capacity'],
#       dtype='object')
